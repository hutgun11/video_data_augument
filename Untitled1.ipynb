# %%
import xml.etree.ElementTree as ET
import cv2
videoFile = "veda_4.mp4"
file_path = r'data_veda_4/frame102_veda_45.xml'
name_product='veda'
name_product = videoFile.replace('.mp4','')
name_product = name_product.replace('.MOV','')
name_product = name_product.replace('.avi','')
tree = ET.parse(file_path)
root = tree.getroot()
for elem in root:
    for subelem in elem:
        for box in subelem:
            if box.tag == 'xmin':
                x1 = int(box.text)
            elif box.tag == 'xmax':
                x2 = int(box.text)
                center_x = (x2+x1)/2
                left = int(center_x-640)
                width = int(center_x+768)
                top=1
                height=1024
                seconds = 0.2
                vidcap = cv2.VideoCapture(videoFile)
                success,image = vidcap.read()
                fps = vidcap.get(cv2.CAP_PROP_FPS) # Gets the frames per second
                # print
                multiplier = int(fps * seconds)
                # print(multiplier)

                #################### Initiate Process ################

                while success:
                    frameId = int(round(vidcap.get(1))) #current frame number, rounded b/c sometimes you get frame intervals which aren't integers...this adds a little imprecision but is likely good enough
                    # print(frameId)
                    success, image = vidcap.read()
                    image = image[ top:top+height, left:left+width ]
                    
                    # print(success)
                    # image=cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
                    path= 'data'+name_product+"/frame"+str(frameId)+"_"+name_product+".jpg" 
                    print(path)
                    if frameId % multiplier == 0:
                        # print('cola',frameId)
                        cv2.imwrite(path, image)
                        print(frameId)

                vidcap.release()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-9995a95fe52c> in <module>
#       7 name_product = name_product.replace('.MOV','')
#       8 name_product = name_product.replace('.avi','')
# ----> 9 tree = ET.parse(file_path)
#      10 root = tree.getroot()
#      11 for elem in root:
#
# ~\Anaconda3\lib\xml\etree\ElementTree.py in parse(source, parser)
#    1195     """
#    1196     tree = ElementTree()
# -> 1197     tree.parse(source, parser)
#    1198     return tree
#    1199
#
# ~\Anaconda3\lib\xml\etree\ElementTree.py in parse(self, source, parser)
#     585         close_source = False
#     586         if not hasattr(source, "read"):
# --> 587             source = open(source, "rb")
#     588             close_source = True
#     589         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data_veda_4/frame102_veda_45.xml'

# %%
import cv2
s_img = cv2.imread("data/data_mix_17_06_32/frame5_mix_17_06_32.jpg")
l_img = cv2.imread("graylight.jpg")
x_offset=y_offset=50
l_img[y_offset:y_offset+s_img.shape[0], x_offset:x_offset+s_img.shape[1]] = s_img
img=l_img[y_offset:y_offset+s_img.shape[0], x_offset:x_offset+s_img.shape[1]]

# %%
img.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-d24c0a253056> in <module>
# ----> 1 img.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'

# %%
from PIL import Image 

img = Image.open("graylight.jpg")  

#Relative Path 
#Image which we want to paste 
img2 = Image.open("data/data_WIN_20200618_11_52_27_Pro/frame5_WIN_20200618_11_52_27_Pro.jpg")  
img.paste(img2, (100, 50)) 

#Saved in the same relative location 
img.save("pasted_picture.jpg")

# %%
from PIL import Image 
import os
img = Image.open("graylight.jpg")  
rootdir=r'data_24_backup/'
extensions=('.jpg','.png')
li=[]
for subdir,dirs,files in os.walk(rootdir):
    for file in files:
        path = os.path.join(subdir,file)
        folder_path=os.path.dirname(path)+'top_floor'
        try:
            if not os.path.exists(folder_path):
                os.makedirs(folder_path)
        except OSError:
            print('Error: Creating dir of data')
        img2 = Image.open(path)  
        img.paste(img2, (80, 500)) 
        img.save(path)
        li.append(path)

# %%
len(set(li))
# Out:
aqufina_gray_cam_2_1_15_gaussian.jpg
# data_gaussian/data_aqufina_gray_cam_2_1_15_gaussian\frame63_aqufina_gray_cam_2_1_15_gaussian.jpg
# data_gaussian/data_aqufina_gray_cam_2_1_15_gaussian\frame66_aqufina_gray_cam_2_1_15_gaussian.jpg
# data_gaussian/data_aqufina_gray_cam_2_1_15_gaussian\frame69_aqufina_gray_cam_2_1_15_gaussian.jpg
# data_gaussian/data_aqufina_gray_cam_2_1_15_gaussian\frame6_aqufina_gray_cam_2_1_15_gaussian.jpg
# data_gaussian/data_aqufina_gray_cam_2_1_15_gaussian\frame72_aqufina_gray_cam_2_1_15_gaussian.jpg
# data_gaussian/data_aqufina_gray_cam_2_1_15_gaussian\frame75_aqufina_gray_cam_2_1_15_gaussian.jpg
# data_gaussian/data_aqufina_gray_cam_2_1_15_gaussian\frame78_aqufina_gray_cam_2_1_15_gaussian.jpg
# data_gaussian/data_aqufina_gray_cam_2_1_15_gaussian\frame81_aqufina_gray_cam_2_1_15_gaussian.jpg
# data_gaussian/data_aqufina_gray_cam_2_1_15_gaussian\frame84_aqufina_gray_cam_2_1_15_gaussian.jpg
# data_gaussian/data_aqufina_gray_cam_2_1_15_gaussian\frame87_aqufina_gray_cam_2_1_15_gaussian.jpg
# data_gaussian/data_aqufina_gray_cam_2_1_15_gaussian\frame90_aqufina_gray_cam_2_1_15_gaussian.jpg
# data_gaussian/data_aqufina_gray_cam_2_1_15_gaussian\frame93_aqufina_gray_cam_2_1_15_gaussian.jpg
# data_gaussian/data_aqufina_gray_cam_2_1_15_gaussian\frame96_aqufina_gray_cam_2_1_15_gaussian.jpg
# data_gaussian/data_aqufina_gray_cam_2_1_15_gaussian\frame99_aqufina_gray_cam_2_1_15_gaussian.jpg
# data_gaussian/data_aqufina_gray_cam_2_1_15_gaussian\frame9_aqufina_gray_cam_2_1_15_gaussian.jpg

# %%
len(set(li))
# Out:
# 1936

# %%
def position_pic(path,path_top):
    img = Image.open("graylight.jpg")  

    img2 = Image.open(path)  
    img.paste(img2, (80, 50)) 
    img.save(path_top.replace('.jpg','')+'_top.jpg') 
#         print(path_top.replace('.jpg','')+'_top.jpg')
    img = Image.open("graylight.jpg") 


    img2 = Image.open(path)  
    img.paste(img2, (80, 400)) 
    img.save(path) 
    img = Image.open("graylight.jpg")

# %%
import cv2

from PIL import Image 
import os
from skimage.util import random_noise
from skimage.io import imsave, imread

img = Image.open("graylight.jpg")  
rootdir=r'data/'
extensions=('.jpg','.png')
for subdir,dirs,files in os.walk(rootdir):
    for file in files:
        path = os.path.join(subdir,file)
        folder_path=os.path.dirname(path).replace('data','data_top')+'_top_floor'
        path_top=os.path.join(folder_path,file)
        folder_gaussian=os.path.dirname(path).replace('data','data_gaussian')+'_gaussian'
        path_gaussian=os.path.join(folder_gaussian,file)
        try:
            if not os.path.exists(folder_path):
                os.makedirs(folder_path)
        except OSError:
            print('Error: Creating dir of data')
        try:
            if not os.path.exists(folder_gaussian):
                os.makedirs(folder_gaussian)
        except OSError:
            print('Error: Creating dir of data') 
        img_gaussian=cv2.imread(path)    
        image_RGB=cv2.cvtColor(img_gaussian,cv2.COLOR_BGR2RGB)
        gauss = random_noise(image_RGB, mode='gaussian', seed=None, clip=True)
        imsave(path_gaussian.replace('.jpg','')+'_gaussian.jpg', gauss)

        gauss_img = Image.open(path_gaussian.replace('.jpg','')+'_gaussian.jpg')  
        img.paste(gauss_img, (80, 400)) 
        img.save(path.replace('.jpg','')+'_gaussian_2_floor.jpg') 
        img = Image.open("graylight.jpg")  
        
        gauss_img = Image.open(path_gaussian.replace('.jpg','')+'_gaussian.jpg')  
        img.paste(gauss_img, (80, 50)) 
        img.save(path_top.replace('.jpg','')+'_gaussian_top_floor.jpg') 
        img = Image.open("graylight.jpg") 

#         cv2.imwrite(path_gaussian.replace('.jpg','')+'_gaussian.jpg', gauss) 
        position_pic(path,path_top)
        
        print(path)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame100_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame105_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame10_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame110_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame115_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame120_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame125_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame130_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame135_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame140_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame145_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame150_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame155_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame15_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame160_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame165_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame170_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame175_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame180_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame185_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame190_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame195_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame200_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame205_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame20_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame210_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame215_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame220_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame225_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame230_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame235_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame240_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame245_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame250_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame255_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame25_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame260_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame265_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame270_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame275_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame280_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame285_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame290_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame295_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame300_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame305_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame30_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame310_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame315_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame320_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame325_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame330_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame335_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame340_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame345_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame350_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame355_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame35_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame360_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame365_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame370_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame375_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame380_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame385_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame390_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame395_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame400_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame405_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame40_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame410_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame415_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame420_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame425_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame430_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame435_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame440_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame445_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame450_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame455_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame45_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame460_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame465_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame470_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame475_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame480_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame485_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame490_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame495_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame500_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame505_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame50_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame510_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame515_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame520_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame525_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame530_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame535_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame540_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame545_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame550_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame555_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame55_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame560_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\frame565_mix_cam2_17_06_27.jpg
# data/data_mix_cam2_17_06_27\frame570_mix_cam2_17_06_27.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# data/data_mix_cam2_17_06_27\fr
cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

adjusted = adjust_gamma(image_RGB, gamma=2)
imsave('cola2.jpg',adjusted)
cv2.imwrite('cola.jpg', cv2.cvtColor(adjusted,cv2.COLOR_RGB2BGR))

plt.figure(figsize=(20,8))
plt.imshow(adjusted)
# Out:
# C:\Users\kasidit.k\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: cola2.jpg is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.

# %%
guassain_blur=cv2.GaussianBlur(image_RGB,(11,11),2)
cv2.imwrite('cola.jpg', cv2.cvtColor(guassain_blur,cv2.COLOR_RGB2BGR))
plt.figure(figsize=(20,8))
plt.imshow(guassain_blur)

# %% [markdown]
# # use

# %%
guassain_blur=cv2.GaussianBlur(image_RGB,(101,101),2)
cv2.imwrite('cola.jpg', cv2.cvtColor(guassain_blur,cv2.COLOR_RGB2BGR))
plt.figure(figsize=(20,8))
plt.imshow(guassain_blur)

# %%
# from PIL import Image 
from skimage.util import random_noise
gauss = random_noise(image_RGB, mode='gaussian', seed=None, clip=True)
plt.imshow(gauss)
cv2.imwrite('cola.jpg', gauss) 

# an=imnoise(img,'gaussian',0.5)
# plt.imshow(an)
# Out:
# True

# %%
bilateral_blur=cv2.bilateralFilter(image_RGB,31,51,51)
plt.figure(figsize=(20,8))
plt.imshow(bilateral_blur)

# %%
def apply_augment(aug0, img):
    return aug0(image=img)['image']

# %%
def batch_apply_augment(aug0,images):
    augmented_images=[]
    for ii in range(len(images)):
        aug_img = apply_augment(aug0,images[ii])
        augmented_images.append(aug_img)

# %%
from albumentations import * 
import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image 


img=cv2.imread('frame5_pepsi_lym_3.jpg',cv2.COLOR_BGR2RGB)
image_RGB=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# aug2 = A.RandomBrightnessContrast(brightness_limit=0.45, contrast_limit=0.45,p=1)
aug1 = Flip(p=0.8)

batch_apply_augment(aug1,image_RGB)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2846     try:
# -> 2847         fp.seek(0)
#    2848     except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: 'list' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-aaac3088c7e5> in <module>
#      12 aug1 = Flip(p=0.8)
#      13
# ---> 14 batch_apply_augment(aug1,image_RGB)
#
# <ipython-input-33-700dd83b8e7d> in batch_apply_augment(aug0, images)
#       4         aug_img = apply_augment(aug0,images[ii])
#       5         augmented_images.append(aug_img)
# ----> 6     img = Image.open(augmented_images)
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2847         fp.seek(0)
#    2848     except (AttributeError, io.UnsupportedOperation):
# -> 2849         fp = io.BytesIO(fp.read())
#    2850         exclusive_fp = True
#    2851
#
# AttributeError: 'list' object has no attribute 'read'

# %%
from albumentations import * 
import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image 
import tensorflow as tf
import tensorflow_docs as tfdocs
import tensorflow_docs.plots




import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      57
# ---> 58   from tensorflow.python.pywrap_tensorflow_internal import *
#      59
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow_internal.py in <module>
#      27             return _mod
# ---> 28     _pywrap_tensorflow_internal = swig_import_helper()
#      29     del swig_import_helper
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow_internal.py in swig_import_helper()
#      23             try:
# ---> 24                 _mod = imp.load_module('_pywrap_tensorflow_internal', fp, pathname, description)
#      25             finally:
#
# ~\Anaconda3\lib\imp.py in load_module(name, file, filename, details)
#     241         else:
# --> 242             return load_dynamic(name, filename, file)
#     243     elif type_ == PKG_DIRECTORY:
#
# ~\Anaconda3\lib\imp.py in load_dynamic(name, path, file)
#     341             name=name, loader=loader, origin=path)
# --> 342         return _load(spec)
#     343
#
# ImportError: DLL load failed: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-21ef557e96c9> in <module>
#       4 from matplotlib import pyplot as plt
#       5 from PIL import Image
# ----> 6 import tensorflow as tf
#       7 import tensorflow_docs as tfdocs
#       8 import tensorflow_docs.plots
#
# ~\Anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>
#      48 import numpy as np
#      49
# ---> 50 from tensorflow.python import pywrap_tensorflow
#      51
#      52 # Protocol buffers
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      67 for some common reasons and solutions.  Include the entire stack trace
#      68 above this error message when asking for help.""" % traceback.format_exc()
# ---> 69   raise ImportError(msg)
#      70
#      71 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "C:\Users\kasidit.k\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 58, in <module>
#     from tensorflow.python.pywrap_tensorflow_internal import *
#   File "C:\Users\kasidit.k\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow_internal.py", line 28, in <module>
#     _pywrap_tensorflow_internal = swig_import_helper()
#   File "C:\Users\kasidit.k\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow_internal.py", line 24, in swig_import_helper
#     _mod = imp.load_module('_pywrap_tensorflow_internal', fp, pathname, description)
#   File "C:\Users\kasidit.k\Anaconda3\lib\imp.py", line 242, in load_module
#     return load_dynamic(name, filename, file)
#   File "C:\Users\kasidit.k\Anaconda3\lib\imp.py", line 342, in load_dynamic
#     return _load(spec)
# ImportError: DLL load failed: The specified module could not be found.
#
#
# Failed to load the native TensorFlow runtime.
#
# See https://www.tensorflow.org/install/errors
#
# for some common reasons and solutions.  Include the entire stack trace
# above this error message when asking for help.

# %%
def visualize(original, augmented):
    fig = plt.figure()
    plt.subplot(1,2,1)
    plt.title('Original image')
    plt.imshow(original)
    plt.subplot(1,2,2)
    plt.title('Augmented image')
    plt.imshow(augmented)

# %%
img = Image.open("frame5_pepsi_lym_3.jpg")
tf.image.random_brightness(img,0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-9094957df562> in <module>
#       1 img = Image.open("frame5_pepsi_lym_3.jpg")
# ----> 2 tf.image.random_brightness(img,0.2)
#
# NameError: name 'tf' is not defined

# %%
import cv2
from PIL import Image 
import os
from skimage.util import random_noise
from skimage.io import imsave, imread
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image 



img = Image.open("graylight.jpg")  
rootdir=r'data/'
extensions=('.jpg','.png')
def position_pic(path,path_top):
#     img = Image.open("graylight.jpg")  

#     img2 = Image.open(path)  
#     img.paste(img2, (80, 50)) 
#     img.save(path_top.replace('.jpg','')+'_top.jpg') 
# #         print(path_top.replace('.jpg','')+'_top.jpg')
#     img = Image.open("graylight.jpg") 

    img = Image.open("graylight.jpg") 
    img2 = Image.open(path)  
    img.paste(img2, (80, 400)) 
    img.save(path) 
    img = Image.open("graylight.jpg") 
def adjust_gamma(image, gamma=1.0):
    # build a lookup table mapping the pixel values [0, 255] to
    # their adjusted gamma values
    invGamma = 1.0 / gamma
    table = np.array([((i / 255.0) ** invGamma) * 255
        for i in np.arange(0, 256)]).astype("uint8")
    # apply gamma correction using the lookup table
    return cv2.LUT(image, table)
for subdir,dirs,files in os.walk(rootdir):
    for file in files:
        ext=os.path.splitext(file)[-1].lower()
        if ext in extensions:
            path = os.path.join(subdir,file)

            folder_path=os.path.dirname(path).replace('data','data_top')+'_top_floor'
            path_top=os.path.join(folder_path,file)

            folder_gaussian=os.path.dirname(path).replace('data','data_gaussian')+'_gaussian'
            path_gaussian=os.path.join(folder_gaussian,file)

            folder_blur=os.path.dirname(path).replace('data','data_blur')+'_blur'
            path_blur=os.path.join(folder_blur,file)

            folder_bright=os.path.dirname(path).replace('data','data_bright')+'_bright'
            path_bright=os.path.join(folder_bright,file)    
        
            try:
                if not os.path.exists(folder_path):
                    os.makedirs(folder_path)
            except OSError:
                print('Error: Creating dir of data')

            try:
                if not os.path.exists(folder_gaussian):
                    os.makedirs(folder_gaussian)
            except OSError:
                print('Error: Creating dir of data') 

            try:
                if not os.path.exists(folder_blur):
                    os.makedirs(folder_blur)
            except OSError:
                print('Error: Creating dir of data') 
            try:    
                if not os.path.exists(folder_bright):
                    os.makedirs(folder_bright)
            except OSError:
                print('Error: Creating dir of data') 

            img_first=cv2.imread(path)    
            image_RGB=cv2.cvtColor(img_first,cv2.COLOR_BGR2RGB)
            #bright
            adjusted = adjust_gamma(image_RGB, gamma=2)
            imsave(path_bright.replace('.jpg','')+'_bright.jpg',adjusted )

            bright_img = Image.open(path_bright.replace('.jpg','')+'_bright.jpg')  
            print(path_bright.replace('.jpg','')+'_bright.jpg')
            img.paste(bright_img, (80, 400)) 
            img.save(path.replace('.jpg','')+'_bright_2_floor.jpg') 
            img = Image.open("graylight.jpg")
#             guassain_blur
            guassain_blur=cv2.GaussianBlur(image_RGB,(101,101),2)
            cv2.imwrite(path_blur.replace('.jpg','')+'_blur.jpg', cv2.cvtColor(guassain_blur,cv2.COLOR_RGB2BGR))
            
            guassain_blur_img = Image.open(path_blur.replace('.jpg','')+'_blur.jpg')  
            img.paste(guassain_blur_img, (80, 400)) 
            img.save(path.replace('.jpg','')+'_blur_2_floor.jpg') 
            img = Image.open("graylight.jpg")

#             guassain_noise
            img_gaussian=cv2.imread(path)    
            image_RGB=cv2.cvtColor(img_gaussian,cv2.COLOR_BGR2RGB)
            gauss_noise = random_noise(image_RGB, mode='gaussian', seed=None, clip=True)
            imsave(path_gaussian.replace('.jpg','')+'_gaussian.jpg', gauss_noise)

            gauss_img = Image.open(path_gaussian.replace('.jpg','')+'_gaussian.jpg')  
            img.paste(gauss_img, (80, 400)) 
            img.save(path.replace('.jpg','')+'_gaussian_2_floor.jpg') 
            img = Image.open("graylight.jpg")  
            
            # gauss_img = Image.open(path_gaussian.replace('.jpg','')+'_gaussian.jpg')  
            # img.paste(gauss_img, (80, 50)) 
            # img.save(path_top.replace('.jpg','')+'_gaussian_top_floor.jpg') 
            # img = Image.open("graylight.jpg") 

    #         cv2.imwrite(path_gaussian.replace('.jpg','')+'_gaussian.jpg', gauss) 
            position_pic(path,path_top)
            
            print(path)
        else:
            path = os.path.join(subdir,file)
            os.remove(path)
            print(path)
# Out:
# data_bright/data_bright_cam1_1_18_bright\frame102_cam1_1_18_bright.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-3-9355ef852ca7> in <module>
#     113
#     114     #         cv2.imwrite(path_gaussian.replace('.jpg','')+'_gaussian.jpg', gauss)
# --> 115             position_pic(path,path_top)
#     116
#     117             print(path)
#
# <ipython-input-3-9355ef852ca7> in position_pic(path, path_top)
#      24
#      25     img2 = Image.open(path)
# ---> 26     img.paste(img2, (80, 400))
#      27     img.save(path)
#      28     img = Image.open("graylight.jpg")
#
# UnboundLocalError: local variable 'img' referenced before assignment

# %%
# Detection and removal based on study [1].
# Note that notations (r_, m_, s_) are adapted from the paper.
import cv2
import numpy as np
import specularity as spc
from matplotlib import pyplot as plt
from PIL import Image 
from skimage.io import imsave, imread

impath = 'test_reflect.jpg'
img = cv2.imread(impath)
gray_img = spc.derive_graym(impath)

r_img = m_img = np.array(gray_img)

rimg = spc.derive_m(img, r_img)
s_img = spc.derive_saturation(img, rimg)
spec_mask = spc.check_pixel_specularity(rimg, s_img)
enlarged_spec = spc.enlarge_specularity(spec_mask)

# use opencv's inpaint methods to remove specularity
radius = 12 
telea = cv2.inpaint(img, enlarged_spec, radius, cv2.INPAINT_TELEA)
ns = cv2.inpaint(img, enlarged_spec, radius, cv2.INPAINT_NS)
# Out:
# E:\pepsi_video_capture\specularity.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
#   s_img[ri,ci] = 1.5*(rimg[ri,ci] - img[ri,ci][0])
# E:\pepsi_video_capture\specularity.py:34: RuntimeWarning: overflow encountered in ubyte_scalars
#   s1 = img[ri,ci][0] + img[ri,ci][2]
# E:\pepsi_video_capture\specularity.py:37: RuntimeWarning: overflow encountered in ubyte_scalars
#   s_img[ri,ci] = 1.5*(img[ri,ci][2] - rimg[ri,ci])

# %%
plt.figure(figsize=(20,8))
plt.imshow(ns)

# %%
plt.figure(figsize=(20,8))
plt.imshow(telea)
